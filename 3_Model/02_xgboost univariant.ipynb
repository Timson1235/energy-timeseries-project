# %%
from xgboost import plot_importance
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

# %%
# Specify the path to the CSV file
url = "https://raw.githubusercontent.com/Timson1235/energy-timeseries-project/803c1688c8fa5a74c19e7a13b69541e42902bffb/Data/merged_cleaned.csv"


# Load the data
load_data = pd.read_csv(url)

# Rename the specific column to "load"
load_data.rename(columns={"Gesamt (Netzlast) [MWh] Berechnete Auflösungen": "load"}, inplace=True)

# Convert the "Date" column to datetime format
load_data['Date'] = pd.to_datetime(load_data['Date'])

# Filter the DataFrame to include only the "Date" and "load" columns
filtered_data = load_data[['Date', 'load']]

# Display the filtered DataFrame
print(filtered_data.head())
# Out:
#                  Date      load
# 0 2018-11-01 00:00:00  48879.50
# 1 2018-11-01 01:00:00  47312.50
# 2 2018-11-01 02:00:00  46093.75
# 3 2018-11-01 03:00:00  46710.50
# 4 2018-11-01 04:00:00  47624.25

# %%
# Plot the load against datetime for visualization
plt.figure(figsize=(12, 6))
plt.plot(filtered_data['Date'], filtered_data['load'], label='Load')
plt.xlabel('Datetime')
plt.ylabel('Load (MWh)')
plt.title('Load Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Extract the start time from the datetime column
filtered_data['Date'] = filtered_data['Date'].apply(lambda x: x.split(' - ')[0] if isinstance(x, str) else x)
# Set the 'datetime' column as the index
filtered_data.set_index('Date', inplace=True)
# Out:
# C:\Users\TimPr\AppData\Local\Temp\ipykernel_40080\2079366551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Date'] = filtered_data['Date'].apply(lambda x: x.split(' - ')[0] if isinstance(x, str) else x)

# %%
filtered_data.index.max()
# Out:
# Timestamp('2024-10-30 23:00:00')

# %%
# Split data into training and testing sets
split_date = '2023-10-30'
train_data = filtered_data.loc[filtered_data.index < split_date].copy()
test_data = filtered_data.loc[filtered_data.index >= split_date].copy()

# %%
# Plot the training and testing sets
plt.figure(figsize=(15, 5))
plt.plot(train_data.index, train_data['load'], label='TRAINING SET', linestyle='-', marker='.')
plt.plot(test_data.index, test_data['load'], label='TEST SET', linestyle='-', marker='.')
plt.title('Actual Load - Training and Testing Sets')
plt.xlabel('Datetime')
plt.ylabel('Actual Load (MW)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Define the function to create features
def create_features(df, label=None):
    """
    Creates time series features from datetime index
    """
    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.isocalendar().week
    
    X = df[['hour', 'dayofweek', 'quarter', 'month', 'year',
            'dayofyear', 'dayofmonth', 'weekofyear']]
    
    if label:
        y = df[label]
        return X, y
    return X

# Define the target label
target_label = 'load'

# Create features and labels for training and testing sets
X_train, y_train = create_features(train_data, label=target_label)
X_test, y_test = create_features(test_data, label=target_label)

# %%
# Initialize the XGBoost Regressor
reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50, objective='reg:squarederror')

# Fit the model with early stopping
reg.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_test, y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-rmse:7483.77316	validation_1-rmse:7494.71593
# [1]	validation_0-rmse:5830.12518	validation_1-rmse:5859.68626
# [2]	validation_0-rmse:4781.97952	validation_1-rmse:4712.80985
# [3]	validation_0-rmse:4075.52722	validation_1-rmse:4087.17252
# [4]	validation_0-rmse:3582.80385	validation_1-rmse:3607.96708
# [5]	validation_0-rmse:3253.89891	validation_1-rmse:3388.45828
# [6]	validation_0-rmse:3024.91442	validation_1-rmse:3172.89729
# [7]	validation_0-rmse:2869.37486	validation_1-rmse:3096.13102
# [8]	validation_0-rmse:2753.03014	validation_1-rmse:3022.84901
# [9]	validation_0-rmse:2599.94955	validation_1-rmse:2990.92406
# [10]	validation_0-rmse:2520.55146	validation_1-rmse:2939.12472
# [11]	validation_0-rmse:2441.13677	validation_1-rmse:2880.16179
# [12]	validation_0-rmse:2321.50557	validation_1-rmse:2872.58699
# [13]	validation_0-rmse:2288.72270	validation_1-rmse:2859.52090
# [14]	validation_0-rmse:2230.91465	validation_1-rmse:2826.35916
# [15]	validation_0-rmse:2197.15426	validation_1-rmse:2817.71081
# [16]	validation_0-rmse:2117.43458	validation_1-rmse:2844.11156
# [17]	validation_0-rmse:2089.42233	validation_1-rmse:2830.02910
# [18]	validation_0-rmse:2042.06391	validation_1-rmse:2822.59743
# [19]	validation_0-rmse:2012.36660	validation_1-rmse:2804.82830
# [20]	validation_0-rmse:1965.98243	validation_1-rmse:2795.59911
# [21]	validation_0-rmse:1932.61837	validation_1-rmse:2825.48302
# [22]	validation_0-rmse:1918.77307	validation_1-rmse:2817.94966
# [23]	validation_0-rmse:1896.12088	validation_1-rmse:2807.90488
# [24]	validation_0-rmse:1822.32464	validation_1-rmse:2832.13766
# [25]	validation_0-rmse:1809.57142	validation_1-rmse:2827.82913
# [26]	validation_0-rmse:1789.09083	validation_1-rmse:2819.84552
# [27]	validation_0-rmse:1770.69926	validation_1-rmse:2822.10692
# [28]	validation_0-rmse:1759.51927	validation_1-rmse:2818.44900
# [29]	validation_0-rmse:1747.81823	validation_1-rmse:2819.49390
# [30]	validation_0-rmse:1741.28827	validation_1-rmse:2819.52475
# [31]	validation_0-rmse:1732.06659	validation_1-rmse:2816.19663
# [32]	validation_0-rmse:1720.63709	validation_1-rmse:2817.20039
# [33]	validation_0-rmse:1710.94958	validation_1-rmse:2817.27205
# [34]	validation_0-rmse:1680.17695	validation_1-rmse:2828.83047
# [35]	validation_0-rmse:1668.19945	validation_1-rmse:2829.34051
# [36]	validation_0-rmse:1652.36078	validation_1-rmse:2829.87526
# [37]	validation_0-rmse:1611.81000	validation_1-rmse:2833.81406
# [38]	validation_0-rmse:1605.48104	validation_1-rmse:2831.88016
# [39]	validation_0-rmse:1552.77659	validation_1-rmse:2861.58872
# [40]	validation_0-rmse:1547.57948	validation_1-rmse:2859.40272
# [41]	validation_0-rmse:1541.44331	validation_1-rmse:2862.36828
# [42]	validation_0-rmse:1532.97610	validation_1-rmse:2858.98372
# [43]	validation_0-rmse:1523.39131	validation_1-rmse:2855.35312
# [44]	validation_0-rmse:1518.73243	validation_1-rmse:2856.95941
# [45]	validation_0-rmse:1509.30981	validation_1-rmse:2860.55379
# [46]	validation_0-rmse:1503.42811	validation_1-rmse:2866.43677
# [47]	validation_0-rmse:1497.04324	validation_1-rmse:2864.26805
# [48]	validation_0-rmse:1487.71525	validation_1-rmse:2874.85737
# [49]	validation_0-rmse:1470.86181	validation_1-rmse:2887.65679
# [50]	validation_0-rmse:1457.81195	validation_1-rmse:2892.49639
# [51]	validation_0-rmse:1454.67200	validation_1-rmse:2893.21026
# [52]	validation_0-rmse:1411.56472	validation_1-rmse:2903.39830
# [53]	validation_0-rmse:1402.60805	validation_1-rmse:2911.87396
# [54]	validation_0-rmse:1397.75841	validation_1-rmse:2912.73192
# [55]	validation_0-rmse:1389.89201	validation_1-rmse:2914.43726
# [56]	validation_0-rmse:1386.74581	validation_1-rmse:2913.96789
# [57]	validation_0-rmse:1381.23858	validation_1-rmse:2914.47465
# [58]	validation_0-rmse:1379.72965	validation_1-rmse:2914.37183
# [59]	validation_0-rmse:1377.90438	validation_1-rmse:2912.66846
# [60]	validation_0-rmse:1354.92401	validation_1-rmse:2928.57266
# [61]	validation_0-rmse:1344.92314	validation_1-rmse:2930.02387
# [62]	validation_0-rmse:1336.57904	validation_1-rmse:2930.18636
# [63]	validation_0-rmse:1325.50027	validation_1-rmse:2924.43060
# [64]	validation_0-rmse:1321.96702	validation_1-rmse:2922.37827
# [65]	validation_0-rmse:1308.31973	validation_1-rmse:2928.58022
# [66]	validation_0-rmse:1299.16347	validation_1-rmse:2926.25193
# [67]	validation_0-rmse:1288.14946	validation_1-rmse:2931.60419
# [68]	validation_0-rmse:1286.89256	validation_1-rmse:2931.16783
# [69]	validation_0-rmse:1276.14332	validation_1-rmse:2929.79767
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Plot feature importance
_ = plot_importance(reg, height=0.9)
plt.show()

# %%
# Add predictions to the test dataset
test_data['load_prediction'] = reg.predict(X_test)

# %%
# Concatenate the training and test datasets
all_data = pd.concat([test_data, train_data], sort=False)

# Ensure the index is a DatetimeIndex and sorted
all_data.index = pd.to_datetime(all_data.index)
all_data = all_data.sort_index()

# %%
# Filter data for September 2024
september_2024_data = all_data.loc['2024-08-01':'2024-09-30']

# Plot actual vs predicted values for September 2024
plt.figure(figsize=(15, 5))
september_2024_data[['load', 'load_prediction']].plot(figsize=(15, 5), title="Actual vs Predicted Load (September 2024)")
plt.xlabel("Date")
plt.ylabel("Actual Load (MWh)")
plt.legend(["Actual", "Predicted"])
plt.grid(True)
plt.show()

# %%
# For one specific date
def plot_day(data, date_str):
    day_data = data.loc[date_str]
    plt.figure(figsize=(12, 6))
    plt.plot(day_data.index, day_data['load'], label='Actual Load', marker='o')
    plt.plot(day_data.index, day_data['load_prediction'], label='Predicted Load', marker='x')
    plt.title(f"Actual vs Predicted Load on {date_str}")
    plt.xlabel("Time")
    plt.ylabel("Load (MWh)")
    plt.legend()
    plt.grid(True)
    plt.show()
plot_day(all_data, '2024-08-28')  # Plot for one day

# %%
# For one specific week
def plot_week(data, start_date, end_date):
    week_data = data.loc[start_date:end_date]
    plt.figure(figsize=(12, 6))
    plt.plot(week_data.index, week_data['load'], label='Actual Load', marker='o')
    plt.plot(week_data.index, week_data['load_prediction'], label='Predicted Load', marker='x')
    plt.title(f"Actual vs Predicted Load from {start_date} to {end_date}")
    plt.xlabel("Date")
    plt.ylabel("Load (MWh)")
    plt.legend()
    plt.grid(True)
    plt.show()
plot_week(all_data, '2024-09-08', '2024-09-13')  # Plot for one week

# %%
# Calculate R^2 and RMSE
# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, test_data['load_prediction'])
mape = mean_absolute_percentage_error(y_test, test_data['load_prediction'])
r2 = r2_score(y_test, test_data['load_prediction'])
rmse = np.sqrt(mean_squared_error(y_test, test_data['load_prediction']))

print(f"R^2: {r2}")
print(f"RMSE: {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
# Out:
# R^2: 0.9109842962211336
# RMSE: 2795.5991053103035
# Mean Absolute Error (MAE): 1988.0795853010834
# Mean Absolute Percentage Error (MAPE): 0.03846298902875898

# %%
#Up next?
#Add Lag variables
#Add holiday indicators.
#Add weather data source.
